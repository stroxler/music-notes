# %% [markdown]
# # Comping voicings for February 21
#
# These arrangements are for strings 5,4,3 exclusively (focusing on these three strings is my bridge to all-fourths tuning!)
#
#
# Still to do:
# - A Day In the Life
# - All the Things
# - Recorda Me
# - Moanin'
# - Strasbourg St Denis
# - So What
#
# - Mercy Mercy Mercy?
# - Spider Man?
# - Cantaloupe Island?

# %%
# %run music21_docs_helpers.py
initialize_music21()
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# {'directoryScratch': None,
#  'lilypondPath': PosixPath('/nix/store/y017wa4qn8dyjd2sjq6q4rldr2yy8mrc-lilypond-2.24.2/bin/lilypond'),
#  'lilypondVersion': '2.24.2',
#  'lilypondFormat': 'pdf',
#  'lilypondBackend': 'ps',
#  'musicxmlPath': PosixPath('/nix/store/b8pajm2klsq44al4500b5ycg2q9hrrr3-musescore-4.1.1/Applications/mscore.app'),
#  'midiPath': PosixPath('/Applications/GarageBand.app'),
#  'graphicsPath': PosixPath('/System/Applications/Preview.app'),
#  'vectorPath': PosixPath('/System/Applications/Preview.app'),
#  'pdfPath': PosixPath('/System/Applications/Preview.app'),
#  'braillePath': None,
#  'musescoreDirectPNGPath': PosixPath('/nix/store/b8pajm2klsq44al4500b5ycg2q9hrrr3-musescore-4.1.1/bin/mscore.'),
#  'showFormat': 'musicxml',
#  'writeFormat': 'musicxml',
#  'ipythonShowFormat': 'ipython.musicxml.png',
# ...

# %%
parse_abc("""
X:1
T:The Night Has a Thousand Eyes
M:4/4
L:1/8
K:G
% A
|: [FBd]8          | [FBd]8          | [Gce]8       | [Gce]4 [Fce]4  |!
   [FBd]8          | [FBd]8          | [Gce]8       | [Gce]4 [Fce]4  |!
   [=Fce]4         | [=FB_e]8        | [EAd]8       | [EAd]8         |!
   [Adf]4 [^Gd=f]4 | [Gce]4 [Fc_e]4  | [EBd]8       |1 [FB_e]8       :|2 [EBd]8 | ]!
% B
   [_E_Bd]8      | [_EAd]8          | [DAc]8        | [DEAc]8       |!
   [_D_Ac]8      | [_DGc]8          | [CG_B]8       | [CG_B]8       |!
   [CGB]8        | [CFB]8           | [EAd]4 [FBe]4 | [^Gdf]8       |!
   [Gce]8        | [Fc_e]8          | [EAd]4 [FBe]4 | [Gce]4 [Fce]4 |
""").show()

# %%
parse_abc("""
X:1
T: Solar
M:4/4
L:1/8
K:Eb
%
| [E=Bd]8         | [E=Bd]8            | [FBc]4 [FBd]4 | [=EB_e]8        |!
| [=E=Ad]8        | [=E=Ac]8           | [EAB]4 [EAc]4 | [DA_d]8         |!
| [DGC]8          | [_D_GB]4  [C_G=B]4 | [_DFc]8       | [_Acf]4 [F=Be]4 |!

""").show()

# %%
parse_abc("""
X:1
T: Four
M:4/4
L:1/8
K:Eb
%
|   [Gdf]8          | [Gdf]8              | [_G_df]8    | [_Gcf]8     |!
|   [_Ace]8         | [_Ace]8             | [=Be_g]8    | [=Bef]8     |!
|   [Beg]8          | [=A=e^g]8 [=A^d^g]8 | [Aeg]8      | [Adg]8      |!
|1  [Beg]8          | [=A=e^g]8 [=A^d^g]8 | [Aeg]8      | [Adg]8      :|!   
|2  [Bf=a]4 [Be_a]4 | [Aeg]4      [Ad^f]4 | [Gcf]8      | [Adg]8      ]|!
""").show()

# %%
parse_abc("""
X:1
T: There Will Never Be Another You
M:4/4
L:1/8
K:Eb
%
|   [Bdg]8          | [Gcf]4  [Bdg]4   | [Acf]8        | [ABf]8           |!
|   [Beg]8          | [Gdf]4   [Beg]4  | [A_df]8       | [G_df]8          |!
|   [Gce]8          | [Ace]4  [A=Bd]4 | [GBd]8        | [F=Be]4 [EBd]4    |!
|1  [E=Ad]8         | [=Aeg]8          | [Aeg]8        | [Adg]8          :|!
|2  [G_df]4 [^Fcf]4 | [GBf]4 [GB=e]4   | [Ace]4 [Adf]4 | [Gcf]4 [Adg]4 ] :|
""").show()

# %%
# This one is trying to mix in a little bit of rootless triad voice leading
parse_abc("""
X:1
T: When You Wish Upon a Star
M:4/4
L:1/8
K:C
% A
|   [Beg]4 [G^cf]4       | [Fcg]2 [Gcf]2 [fce]4      |   [GBf]4 [FBe]4   | [^FA_e]4 [GBe]4             |!
|   [Adg]4 [AB^f]4       | [Acf]4   [Bdf]4           | [cfa]4  [Bfa]8    |1 [Beg]4 [cfa]2 [Bf_a]2     :|!
                                                                         |2 [ceg]8                    ]|!
# %B
| [FAc]4 [FBd]4          | [GBe]4 [G^ce]4            | [Acf]4 [Bdf]4     | [B_e^f]4 [Beg]4             |!
| [cea]8                 |  [c^f^g]4 [c^fa]4         | [cfa]8            | [Bfa]4   [Bf_a]4            |!
""").show()

# %%
# This one is *really* emphasizing rootless triad voice leading
parse_abc("""
X:1
T: Stella by Starlight
M:4/4
L:1/2
K:Bb
% A1
| [DGB]2   | [EG^c]2       | [EGB]2  | [EAc]2         |!
| [E_Ac]2  | [F_Ad]2       | [GBd]2  | [_Gce]2        |!
% B1
| [FAd]2   | [GBd] [G^ce]  | [Acf]2  | [_A_df] [B_dg] |!
| [Aeg]2   | [Bdg] [G^cf]  | [Gce]2  | [^Fcf] [^Fcd]  |!
% C (bridge)
| [F=Be]2  | [F=Be]2       | [EBd]2  | [EBd]2         |!
| [EAd]2   | [EAd]2        | [DAc]2  | [DAc]2          |!
% A2
| [DGB]2   | [EG^c]2       | [FAc]2  | [FBd]2         |!
| [_GBe]2  | [FAe]2        | [FAd]2  | [DAc]2         |!
""").show()

# %%
# This one demonstrates going up with rootles triads and then down with standard voice leading (on B2)
parse_abc("""
X:1
T: On Green Dolphin St
M:4/4
L:1/2
K:Eb
% A
| [EGB]2        | [EGB]2        | [E_GB]2     | [E_GB]2         |!
| E=Ac]2        | [EA=B]2       | [EGB]2      | [=EGB]2         |!
% B1
|1 [EAc]2       | [FAd]2        | [GBd]2      | [Gdf]2         |!
|  [_G=Be]2     | [F=Be]2       | [FBd]2      | [EAc] [DA=B]   |!
% B2
|2 [EAc]2       | [FAc] [F=BD]  | [GBe]2      | [Gce] [^Fce]   |!
|  [FBd] [=EBd] | [EAc] [DAc]   |  [DGB]2     | [EAc] [DA=B] ]|!
""").show()

# %%
parse_abc("""
X:1
T: Caravan
M:4/4
L:1/1
K:Ab
% A
| [B=ea]          | [B=ea]        | [B=ea]    | [B=ea]         |!
| [B=ea]          | [B=ea]        | [B=ea]    | [B=ea]         |!
| [A^dg]          | [A^dg]        | [A^dg]    | [A^dg]        :|!
# %B
| [=Aeg]          | [=Aeg]        | [=Aeg]    | [=Aeg]           |!
| [A=dg]          | [A=dg]        | [A=dg]    | [A=dg]            |!
| [Gdf]           | [Gdf]         | [Gdf]     | [Gdf]             |!
| [Bcf]           | [Bcf]         | [=EBe]    | [B=ea]/2 [CF=a]/2 |!
""").show()

# %%
parse_abc("""
X:1
T: Manhã de Carnaval
M:4/4
L:1/2
K:C
% A1
| [EAB] [EAc]     | [FAd] [D^Gc]  | [EAB] [EAc]     | [FAd] [D^Gc]  |!
| [EAB] [EAc]     | [FAc] [FBd]   | [GBe] [Ade]     | [_B^cE]       |!
| [Acf]2          | [_ABf]2       | [GBe]2          | [Ace]         |!
| [Adf]2          | [^Gdg]2       | [Ace]2          | [Adf] [^Gdg]  |!
# %A2
| [EAB]  [EAc]    | [FAd] [D^Gc]  | [EAB] [EAc]     | [FAd] [D^Gc]  |!
| [DG_B]2         | [^CGc]2       | [FAc]2          | [Fce]2        |!
| [Gcf] [Fcg]     | [Adf] [^Gdg]  | [Acg] [GBe]     | [Fae]2        |!
| [FAd]2          | [D^Gc]        | [EAB] [EAc]     | [Adf] [^Gdg]  |!
""").show()
